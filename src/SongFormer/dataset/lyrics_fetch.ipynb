# %%
import os
import re
import time
import json
import math
import unicodedata
from difflib import SequenceMatcher

import requests
import pandas as pd
from tqdm.auto import tqdm

from pathlib import Path

# %% [markdown]
# ### HX

# %%
METADATA_PATH = "/mnt/ssd/hbli/datasets/harmonixset/metadata.csv"
OUTPUT_CSV = "/mnt/ssd/hbli/datasets/harmonixset/harmonixset_lrclib_results.csv"
OUTPUT_JSONL = "/mnt/ssd/hbli/datasets/harmonixset/harmonixset_lrclib_results.jsonl"

CHECKPOINT_EVERY = 50            # save once after per CHECKPOINT_EVERY
SLEEP_BETWEEN_REQUESTS = 0.25    # limit speed
TIMEOUT = 20
MAX_RETRIES = 3

MIN_ACCEPT_SCORE = 0.72

LRCLIB_GET_URL = "https://lrclib.net/api/get"
LRCLIB_SEARCH_URL = "https://lrclib.net/api/search"

# %%
# metadata, use cols
df = pd.read_csv(METADATA_PATH)

required_cols = ["File", "Title", "Artist", "Release", "Duration"]
work_df = df[required_cols].copy()

for col in ["File", "Title", "Artist", "Release"]:
    work_df[col] = work_df[col].fillna("").astype(str).str.strip()

work_df["Duration"] = pd.to_numeric(work_df["Duration"], errors="coerce")
work_df = work_df.dropna(subset=["Duration"]).reset_index(drop=True)
print("total count", len(work_df))

# %%
def strip_accents(text: str) -> str:
    text = unicodedata.normalize("NFKD", text)
    return "".join(ch for ch in text if not unicodedata.combining(ch))

def normalize_text(text: str) -> str:
    if text is None:
        return ""
    text = str(text).lower().strip()
    text = strip_accents(text)

    # delete such as (Remastered), [Live], (feat. xxx)
    text = re.sub(r"\([^)]*\)", " ", text)
    text = re.sub(r"\[[^\]]*\]", " ", text)

    noise_patterns = [
        r"\bfeat\.?.*$",
        r"\bft\.?.*$",
        r"\bfeaturing\b.*$",
        r"\bremaster(ed)?\b",
        r"\blive\b",
        r"\bversion\b",
        r"\bedit\b",
        r"\bmix\b",
        r"\bmono\b",
        r"\bstereo\b",
        r"\bexplicit\b",
        r"\bdeluxe\b",
    ]
    for p in noise_patterns:
        text = re.sub(p, " ", text)

    # delete punctuation
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def similarity(a: str, b: str) -> float:
    a = normalize_text(a)
    b = normalize_text(b)
    if not a and not b:
        return 1.0
    if not a or not b:
        return 0.0
    return SequenceMatcher(None, a, b).ratio()

# %%
def sec_to_api_duration(x):
    if pd.isna(x):
        return None
    return int(round(float(x)))

def normalize_duration_to_sec(x):
    if x is None or (isinstance(x, float) and math.isnan(x)):
        return None

    x = float(x)

    # if > 10000，must be ms
    if x > 10000:
        return x / 1000.0
    return x

# %%
session = requests.Session()

def request_json(url, params, max_retries=MAX_RETRIES, timeout=TIMEOUT):
    last_error = None

    for attempt in range(max_retries):
        try:
            resp = session.get(url, params=params, timeout=timeout)

            if resp.status_code == 404:
                return None

            if resp.status_code == 429:
                # wait when 429
                wait = 2 ** attempt
                time.sleep(wait)
                continue

            resp.raise_for_status()
            return resp.json()

        except requests.RequestException as e:
            last_error = str(e)
            wait = 2 ** attempt
            time.sleep(wait)

    print(f"[WARN] fail request: {url}, params={params}, err={last_error}")
    return None

# %%
# accurate fetch
def lrclib_get(title, artist, release=None, duration_sec=None):
    """
    title + artist + duration
    """
    params = {
        "track_name": title,
        "artist_name": artist,
    }

    if release:
        params["album_name"] = release

    if duration_sec is not None and not pd.isna(duration_sec):
        params["duration"] = sec_to_api_duration(duration_sec)

    data = request_json(LRCLIB_GET_URL, params)
    time.sleep(SLEEP_BETWEEN_REQUESTS)
    return data

# %%
# fuzzy match
def lrclib_search(title, artist, release=None, duration_sec=None):
    """
    if fail in get, use search api
    """
    params = {
        "track_name": title,
        "artist_name": artist,
        "q": f"{title} {artist}".strip()
    }

    if release:
        params["album_name"] = release

    if duration_sec is not None and not pd.isna(duration_sec):
        params["duration"] = sec_to_api_duration(duration_sec)

    data = request_json(LRCLIB_SEARCH_URL, params)
    time.sleep(SLEEP_BETWEEN_REQUESTS)

    if data is None:
        return []
    if isinstance(data, list):
        return data
    return []

# %%
def get_field(d, *keys):
    for k in keys:
        if k in d and d[k] is not None:
            return d[k]
    return None

def score_candidate(row, cand):
    """
    score for result, depends on title, artist, album, duration
    """
    cand_title = get_field(cand, "trackName", "track_name", "name", "title")
    cand_artist = get_field(cand, "artistName", "artist_name", "artist")
    cand_album = get_field(cand, "albumName", "album_name", "album")
    cand_duration = get_field(cand, "duration")

    title_score = similarity(row["Title"], cand_title)
    artist_score = similarity(row["Artist"], cand_artist)
    album_score = similarity(row["Release"], cand_album) if row["Release"] else 0.0

    row_dur = float(row["Duration"])
    cand_dur = normalize_duration_to_sec(cand_duration)
    if cand_dur is None:
        duration_score = 0.0
        duration_diff = None
    else:
        duration_diff = abs(row_dur - cand_dur)
        # >15, 0
        duration_score = max(0.0, 1.0 - min(duration_diff, 15.0) / 15.0)

    final_score = (
        0.50 * title_score +
        0.30 * artist_score +
        0.15 * album_score +
        0.05 * duration_score
    )

    return {
        "final_score": final_score,
        "title_score": title_score,
        "artist_score": artist_score,
        "album_score": album_score,
        "duration_score": duration_score,
        "duration_diff_sec": duration_diff,
    }

# %%
def build_result_row(row, matched, method, score_info=None, status="matched", error_msg=None):
    if matched is None:
        return {
            "File": row["File"],
            "Title": row["Title"],
            "Artist": row["Artist"],
            "Release": row["Release"],
            "Duration": row["Duration"],
            "status": status,
            "match_method": method,
            "match_score": None if score_info is None else score_info.get("final_score"),
            "title_score": None if score_info is None else score_info.get("title_score"),
            "artist_score": None if score_info is None else score_info.get("artist_score"),
            "album_score": None if score_info is None else score_info.get("album_score"),
            "duration_score": None if score_info is None else score_info.get("duration_score"),
            "duration_diff_sec": None if score_info is None else score_info.get("duration_diff_sec"),
            "lrclib_id": None,
            "matched_track": None,
            "matched_artist": None,
            "matched_album": None,
            "matched_duration": None,
            "instrumental": None,
            "plain_lyrics": None,
            "synced_lyrics": None,
            "has_plain": False,
            "has_synced": False,
            "error": error_msg,
        }

    lrclib_id = get_field(matched, "id")
    cand_title = get_field(matched, "trackName", "track_name", "name", "title")
    cand_artist = get_field(matched, "artistName", "artist_name", "artist")
    cand_album = get_field(matched, "albumName", "album_name", "album")
    cand_duration = get_field(matched, "duration")
    instrumental = get_field(matched, "instrumental")
    plain_lyrics = get_field(matched, "plainLyrics", "plain_lyrics")
    synced_lyrics = get_field(matched, "syncedLyrics", "synced_lyrics")

    return {
        "File": row["File"],
        "Title": row["Title"],
        "Artist": row["Artist"],
        "Release": row["Release"],
        "Duration": row["Duration"],
        "status": status,
        "match_method": method,
        "match_score": None if score_info is None else score_info.get("final_score"),
        "title_score": None if score_info is None else score_info.get("title_score"),
        "artist_score": None if score_info is None else score_info.get("artist_score"),
        "album_score": None if score_info is None else score_info.get("album_score"),
        "duration_score": None if score_info is None else score_info.get("duration_score"),
        "duration_diff_sec": None if score_info is None else score_info.get("duration_diff_sec"),
        "lrclib_id": lrclib_id,
        "matched_track": cand_title,
        "matched_artist": cand_artist,
        "matched_album": cand_album,
        "matched_duration": normalize_duration_to_sec(cand_duration),
        "instrumental": instrumental,
        "plain_lyrics": plain_lyrics,
        "synced_lyrics": synced_lyrics,
        "has_plain": bool(plain_lyrics),
        "has_synced": bool(synced_lyrics),
        "error": error_msg,
    }


def resolve_one_song(row):
    # ---------- Step 1: exact get ----------
    exact = lrclib_get(
        title=row["Title"],
        artist=row["Artist"],
        release=row["Release"],
        duration_sec=row["Duration"]
    )

    if exact:
        exact_score = score_candidate(row, exact)
        if exact_score["final_score"] >= MIN_ACCEPT_SCORE:
            return build_result_row(
                row=row,
                matched=exact,
                method="get_exact",
                score_info=exact_score,
                status="matched"
            )

    # ---------- Step 2: search fallback ----------
    candidates = lrclib_search(
        title=row["Title"],
        artist=row["Artist"],
        release=row["Release"],
        duration_sec=row["Duration"]
    )

    if not candidates:
        return build_result_row(
            row=row,
            matched=None,
            method="search_fallback",
            score_info=None,
            status="not_found"
        )

    scored = []
    for cand in candidates:
        s = score_candidate(row, cand)
        scored.append((cand, s))

    scored.sort(key=lambda x: x[1]["final_score"], reverse=True)
    best_cand, best_score = scored[0]

    status = "matched" if best_score["final_score"] >= MIN_ACCEPT_SCORE else "low_confidence"

    return build_result_row(
        row=row,
        matched=best_cand,
        method="search_fallback",
        score_info=best_score,
        status=status
    )

# %%
if os.path.exists(OUTPUT_CSV):
    existing = pd.read_csv(OUTPUT_CSV)
    done_files = set(existing["File"].astype(str).tolist())
    print(f"already have {len(existing)}, skip")
else:
    existing = pd.DataFrame()
    done_files = set()

todo_df = work_df[~work_df["File"].astype(str).isin(done_files)].reset_index(drop=True)
print("wait for processing：", len(todo_df))
display(todo_df.head())

# %%
results = []

for idx, row in tqdm(todo_df.iterrows(), total=len(todo_df)):
    try:
        out = resolve_one_song(row)
    except Exception as e:
        out = build_result_row(
            row=row,
            matched=None,
            method="internal_error",
            score_info=None,
            status="error",
            error_msg=str(e)
        )

    results.append(out)

    if (idx + 1) % CHECKPOINT_EVERY == 0 or (idx + 1) == len(todo_df):
        new_df = pd.DataFrame(results)

        if len(existing) > 0:
            save_df = pd.concat([existing, new_df], ignore_index=True)
        else:
            save_df = new_df.copy()

        save_df.to_csv(OUTPUT_CSV, index=False, encoding="utf-8-sig")

        with open(OUTPUT_JSONL, "w", encoding="utf-8") as f:
            for _, r in save_df.iterrows():
                f.write(json.dumps(r.to_dict(), ensure_ascii=False) + "\n")

        print(f"[checkpoint] have saved to {OUTPUT_CSV} / {OUTPUT_JSONL}")

# %%
# final result
final_df = pd.read_csv(OUTPUT_CSV)

# %%
final_df['status'].value_counts()

# %%
final_df[final_df['status'] == 'low_confidence']

# %%
final_df[final_df['status'] == 'not_found']

# %% [markdown]
# ### Hook

# %%
def score_candidate(row, cand):
    cand_title = get_field(cand, "trackName", "track_name", "name", "title")
    cand_artist = get_field(cand, "artistName", "artist_name", "artist")

    title_score = similarity(row["Title"], cand_title)
    artist_score = similarity(row["Artist"], cand_artist)

    final_score = 0.5 * title_score + 0.5 * artist_score

    return {
        "final_score": final_score,
        "title_score": title_score,
        "artist_score": artist_score,
        "album_score": None,
        "duration_score": None,
        "duration_diff_sec": None,
    }

# %%
def build_result_row(row, matched, method, score_info=None, status="matched", error_msg=None):
    base = {
        "File": row["File"],
        "AudioPath": row.get("AudioPath", None),
        "Title": row["Title"],
        "Artist": row["Artist"],
        "Release": row.get("Release", ""),
        "Duration": row.get("Duration", None),
        "status": status,
        "match_method": method,
        "match_score": None if score_info is None else score_info.get("final_score"),
        "title_score": None if score_info is None else score_info.get("title_score"),
        "artist_score": None if score_info is None else score_info.get("artist_score"),
        "album_score": None if score_info is None else score_info.get("album_score"),
        "duration_score": None if score_info is None else score_info.get("duration_score"),
        "duration_diff_sec": None if score_info is None else score_info.get("duration_diff_sec"),
        "error": error_msg,
    }

    if matched is None:
        base.update({
            "lrclib_id": None,
            "matched_track": None,
            "matched_artist": None,
            "matched_album": None,
            "matched_duration": None,
            "instrumental": None,
            "plain_lyrics": None,
            "synced_lyrics": None,
            "has_plain": False,
            "has_synced": False,
        })
        return base

    lrclib_id = get_field(matched, "id")
    cand_title = get_field(matched, "trackName", "track_name", "name", "title")
    cand_artist = get_field(matched, "artistName", "artist_name", "artist")
    cand_album = get_field(matched, "albumName", "album_name", "album")
    cand_duration = get_field(matched, "duration")
    instrumental = get_field(matched, "instrumental")
    plain_lyrics = get_field(matched, "plainLyrics", "plain_lyrics")
    synced_lyrics = get_field(matched, "syncedLyrics", "synced_lyrics")

    base.update({
        "lrclib_id": lrclib_id,
        "matched_track": cand_title,
        "matched_artist": cand_artist,
        "matched_album": cand_album,
        "matched_duration": cand_duration,
        "instrumental": instrumental,
        "plain_lyrics": plain_lyrics,
        "synced_lyrics": synced_lyrics,
        "has_plain": bool(plain_lyrics),
        "has_synced": bool(synced_lyrics),
    })
    return base

# %%
def resolve_one_song(row):
    exact = lrclib_get(
        title=row["Title"],
        artist=row["Artist"],
    )

    if exact:
        exact_score = score_candidate(row, exact)
        if exact_score["final_score"] >= MIN_ACCEPT_SCORE:
            return build_result_row(
                row=row,
                matched=exact,
                method="get_exact",
                score_info=exact_score,
                status="matched"
            )

    candidates = lrclib_search(
        title=row["Title"],
        artist=row["Artist"],
    )

    if not candidates:
        return build_result_row(
            row=row,
            matched=None,
            method="search_fallback",
            score_info=None,
            status="not_found"
        )

    scored = []
    for cand in candidates:
        s = score_candidate(row, cand)
        scored.append((cand, s))

    scored.sort(key=lambda x: x[1]["final_score"], reverse=True)
    best_cand, best_score = scored[0]

    status = "matched" if best_score["final_score"] >= MIN_ACCEPT_SCORE else "low_confidence"

    return build_result_row(
        row=row,
        matched=best_cand,
        method="search_fallback",
        score_info=best_score,
        status=status
    )

# %%
def load_scp_paths(scp_path: str):
    paths = []
    with open(scp_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            parts = line.split()
            path = parts[-1]
            paths.append(path)

    return paths


def parse_hooktheory_filename(audio_path: str):
    """
    e.g., 070-shake_guilty-conscience_kygz-KaPmKB.mp3
    """
    fname = Path(audio_path).name
    stem = Path(audio_path).stem

    parts = stem.split("_")
    if len(parts) < 2:
        raise ValueError(f"file name exception: {fname}")

    artist_raw, title_raw = parts[0], parts[1]

    artist = artist_raw.replace("-", " ").strip()
    title = title_raw.replace("-", " ").strip()

    return {
        "File": fname,
        "AudioPath": audio_path,
        "Artist": artist,
        "Title": title,
    }


def build_work_df_from_hooktheory_scp(scp_path: str):
    audio_paths = load_scp_paths(scp_path)

    rows = []
    bad_rows = []

    for p in tqdm(audio_paths, desc="Parsing HookTheory scp"):
        try:
            item = parse_hooktheory_filename(p)
            rows.append(item)
        except Exception as e:
            bad_rows.append({
                "AudioPath": p,
                "error": str(e)
            })

    work_df = pd.DataFrame(rows)
    bad_df = pd.DataFrame(bad_rows)

    print(f"success {len(work_df)} 条")
    print(f"fail {len(bad_df)} 条")

    return work_df, bad_df

# %%
SCP_PATH = "/home/hbli/songformer/repo/SongFormer/runs/hx_train_hooktheory_v3/results/hooktheory_all_unique.scp"

work_df, bad_df = build_work_df_from_hooktheory_scp(SCP_PATH)

display(work_df.head())
display(bad_df.head())

# %%
OUTPUT_CSV = "/home/z/下载/hooktheory_lyrics/hooktheory_lrclib_results.csv"
OUTPUT_JSONL = "/home/z/下载/hooktheory_lyrics/hooktheory_lrclib_results.jsonl"
CHECKPOINT_EVERY = 50

if os.path.exists(OUTPUT_CSV):
    existing = pd.read_csv(OUTPUT_CSV)
    done_files = set(existing["File"].astype(str).tolist())
    print(f"already have {len(existing)}, skip")
else:
    existing = pd.DataFrame()
    done_files = set()

todo_df = work_df[~work_df["File"].astype(str).isin(done_files)].reset_index(drop=True)
print("wait for processing: ", len(todo_df))

results = []

for idx, row in tqdm(todo_df.iterrows(), total=len(todo_df), desc="Fetching lyrics"):
    try:
        out = resolve_one_song(row)
    except Exception as e:
        out = build_result_row(
            row=row,
            matched=None,
            method="internal_error",
            score_info=None,
            status="error",
            error_msg=str(e)
        )

    results.append(out)

    # save
    if (idx + 1) % CHECKPOINT_EVERY == 0 or (idx + 1) == len(todo_df):
        new_df = pd.DataFrame(results)

        if len(existing) > 0:
            save_df = pd.concat([existing, new_df], ignore_index=True)
        else:
            save_df = new_df.copy()

        save_df.to_csv(OUTPUT_CSV, index=False, encoding="utf-8-sig")

        with open(OUTPUT_JSONL, "w", encoding="utf-8") as f:
            for _, r in save_df.iterrows():
                f.write(json.dumps(r.to_dict(), ensure_ascii=False) + "\n")

        print(f"[checkpoint] have save to:\n  {OUTPUT_CSV}\n  {OUTPUT_JSONL}")

# %%
final_df = pd.read_csv(OUTPUT_CSV)
len(final_df[final_df['plain_lyrics'].notna()]), len(final_df)

# %% [markdown]
# ### lyrics result check

# %%
df = pd.read_csv("/home/z/下载/hooktheory_lyrics/hooktheory_lrclib_results.csv")

# %%
df.columns
# Out:
# Index(['File', 'AudioPath', 'Title', 'Artist', 'Release', 'Duration', 'status',
#        'match_method', 'match_score', 'title_score', 'artist_score',
#        'album_score', 'duration_score', 'duration_diff_sec', 'error',
#        'lrclib_id', 'matched_track', 'matched_artist', 'matched_album',
#        'matched_duration', 'instrumental', 'plain_lyrics', 'synced_lyrics',
#        'has_plain', 'has_synced'],
#       dtype='object')

# %%
df[(df['match_score'] < 0.6) & (df['instrumental'] == False)][['File', 'AudioPath', 'Title', 'Artist', 'Release', 'Duration', 'matched_track', 'matched_artist', 'matched_album',
       'matched_duration', 'status', 'match_score', 'instrumental']]
# Out:
#                                                    File  \
# 106   adam-szabo-and-johan-vilborg_two-to-one_AaoGWX...
# 269   all-my-friends-ft-tinashe---chance-the-rapper_...
# 270      allemaal-door-jou_bart-peeters_dPoDAKORmnM.mp3
# 309                         amber_ocean_VMgJzXkDgqK.mp3
# 515           arty_ferry-corsten---punk_nJmBJzrWmAV.mp3
# 730      bastion-soundtrack_zulfs-theme_ZdPoDPVqonM.mp3
# 809   beautiful-liar_beyonce-and-shakira_dPoDJkLBgnM...
# 864       better-off-alone_alice-deejay_pyvgPZGLoYq.mp3
# 1414                cartoons_ekkosangen_QLgnkeYvx-V.mp3
# 1422    cash-cash_speak-with-your-heart_QLgnaJy_m-V.mp3
# 1433                        cat_you-are_nLga_YJloYp.mp3
# 1714                cosmic-girls_secret_ANmpByKPxyM.mp3
# 1938                               dd_d_Rzoj_vXkmDe.mp3
# 2790               fromis_9_glass-shoes_AaoGQVAkgeQ.mp3
# 2802    futurama-theme_christopher-tyng_JkmZQbdjoqn.mp3
# 2977         goodbye-everyone_siinamota_JNgqJGNexrz.mp3
# 3200  henry-viii_pastime-with-good-company_WeglPArag...
# 3227  himouto-umaru-chan_himouto-umaru-chan-op_jDgXr...
# 3351          i-love-your-smile_shanice_Nlamk__vmDM.mp3
# 3385  im-so-lonesome-i-could-cry_by-hank-williams_Zb...
# 3516                    jackson_outkast_JkmZnvJJmqn.mp3
# 3652      jerry-goldsmith_flying-dreams_JkmZKD--gqn.mp3
# 4063  katamari-damacy-soundtrack_katamari-on-the-roc...
# 4426  lady-gaga_where-do-you-think-youre-goin_nJmBKl...
# 4551                  like-i-would_zayn_lamkkWqZmDM.mp3
# 4587  lily-white_love-live---shunjou-romantic_JNgqla...
# 5296                      moguai_champs_yvmrzeBlmOW.mp3
# 5651  nintendo_lifelight---super-smash-bros-ultimate...
# 5652  nintendo_lifelight---super-smash-bros_QLgnPXnE...
# 5732              norgaard_the-vaccines_d_gwWvbrgGV.mp3
# 6027                pharaoh_on-the-moon_bWgMvMZXxlX.mp3
# 6374  rebecca-sugar_lets-only-think-about-love---ste...
# 6655  said-the-sky-and-illenium_painted-white---au5-...
# 6658  saint-snow_love-live---crash-mind_nLgadvXGmYp.mp3
# 6733                      scandal_queen__QLgnJ_Pg-V.mp3
# 6793  sebastian_love-in-motion---skrillex-remix_ROmN...
# 7323  spongebob-squarepants_loop-de-loop_nJmBP-w_xAV...
# 7470              summer-school_control_nZgWOArwgry.mp3
# 7635      tennyson-x-mr-carmack_tuesday_dPoD-yjqmnM.mp3
# 7988  the-killing-moon_echo-and-the-bunnymen_YAg-kRP...
# 8255                   the-xx_open-eyes_yvgPanNYxYq.mp3
# 8277   these-new-puritans_v-island-song_AaoGPLkzmeQ.mp3
# 8336               tidal-wave_sub-focus_pyvgPOnLmYq.mp3
# 8810  yuki-nagato_yuki-muon-madobe-nite_KexEbElXo_B.mp3
#
#                                               AudioPath  \
# 106   /home/z/下载/打包结果_audio/adam-szabo-and-johan-vil...
# 269   /home/z/下载/打包结果_audio/all-my-friends-ft-tinash...
# 270   /home/z/下载/打包结果_audio/allemaal-door-jou_bart-p...
# 309   /home/z/下载/打包结果_audio/amber_ocean_VMgJzXkDgqK.mp3
# 515   /home/z/下载/打包结果_audio/arty_ferry-corsten---pun...
# 730   /home/z/下载/打包结果_audio/bastion-soundtrack_zulfs...
# 809   /home/z/下载/打包结果_audio/beautiful-liar_beyonce-a...
# 864   /home/z/下载/打包结果_audio/better-off-alone_alice-d...
# 1414  /home/z/下载/打包结果_audio/cartoons_ekkosangen_QLgn...
# 1422  /home/z/下载/打包结果_audio/cash-cash_speak-with-you...
# 1433  /home/z/下载/打包结果_audio/cat_you-are_nLga_YJloYp.mp3
# 1714  /home/z/下载/打包结果_audio/cosmic-girls_secret_ANmp...
# 1938         /home/z/下载/打包结果_audio/dd_d_Rzoj_vXkmDe.mp3
# 2790  /home/z/下载/打包结果_audio/fromis_9_glass-shoes_Aao...
# 2802  /home/z/下载/打包结果_audio/futurama-theme_christoph...
# 2977  /home/z/下载/打包结果_audio/goodbye-everyone_siinamo...
# 3200  /home/z/下载/打包结果_audio/henry-viii_pastime-with-...
# 3227  /home/z/下载/打包结果_audio/himouto-umaru-chan_himou...
# 3351  /home/z/下载/打包结果_audio/i-love-your-smile_shanic...
# 3385  /home/z/下载/打包结果_audio/im-so-lonesome-i-could-c...
# 3516  /home/z/下载/打包结果_audio/jackson_outkast_JkmZnvJJ...
# 3652  /home/z/下载/打包结果_audio/jerry-goldsmith_flying-d...
# 4063  /home/z/下载/打包结果_audio/katamari-damacy-soundtra...
# 4426  /home/z/下载/打包结果_audio/lady-gaga_where-do-you-t...
# 4551  /home/z/下载/打包结果_audio/like-i-would_zayn_lamkkW...
# 4587  /home/z/下载/打包结果_audio/lily-white_love-live---s...
# 5296  /home/z/下载/打包结果_audio/moguai_champs_yvmrzeBlmO...
# 5651  /home/z/下载/打包结果_audio/nintendo_lifelight---sup...
# 5652  /home/z/下载/打包结果_audio/nintendo_lifelight---sup...
# 5732  /home/z/下载/打包结果_audio/norgaard_the-vaccines_d_...
# 6027  /home/z/下载/打包结果_audio/pharaoh_on-the-moon_bWgM...
# 6374  /home/z/下载/打包结果_audio/rebecca-sugar_lets-only-...
# 6655  /home/z/下载/打包结果_audio/said-the-sky-and-illeniu...
# 6658  /home/z/下载/打包结果_audio/saint-snow_love-live---c...
# 6733  /home/z/下载/打包结果_audio/scandal_queen__QLgnJ_Pg-...
# 6793  /home/z/下载/打包结果_audio/sebastian_love-in-motion...
# 7323  /home/z/下载/打包结果_audio/spongebob-squarepants_lo...
# 7470  /home/z/下载/打包结果_audio/summer-school_control_nZ...
# 7635  /home/z/下载/打包结果_audio/tennyson-x-mr-carmack_tu...
# 7988  /home/z/下载/打包结果_audio/the-killing-moon_echo-an...
# 8255  /home/z/下载/打包结果_audio/the-xx_open-eyes_yvgPanN...
# 8277  /home/z/下载/打包结果_audio/these-new-puritans_v-isl...
# 8336  /home/z/下载/打包结果_audio/tidal-wave_sub-focus_pyv...
# 8810  /home/z/下载/打包结果_audio/yuki-nagato_yuki-muon-ma...
#
#                                              Title  \
# 106                                     two to one
# 269                                      snakehips
# 270                                   bart peeters
# 309                                          ocean
# 515                           ferry corsten   punk
# 730                                    zulfs theme
# 809                            beyonce and shakira
# 864                                   alice deejay
# 1414                                    ekkosangen
# 1422                         speak with your heart
# 1433                                       you are
# 1714                                        secret
# 1938                                             d
# 2790                                             9
# 2802                              christopher tyng
# 2977                                     siinamota
# 3200                     pastime with good company
# 3227                         himouto umaru chan op
# 3351                                       shanice
# 3385                              by hank williams
# 3516                                       outkast
# 3652                                 flying dreams
# 4063                         katamari on the rocks
# 4426                 where do you think youre goin
# 4551                                          zayn
# 4587                  love live   shunjou romantic
# 5296                                        champs
# 5651         lifelight   super smash bros ultimate
# 5652                  lifelight   super smash bros
# 5732                                  the vaccines
# 6027                                   on the moon
# 6374  lets only think about love   steven universe
# 6655         painted white   au5 and fractal remix
# 6658                        love live   crash mind
# 6733                                         queen
# 6793               love in motion   skrillex remix
# 7323                                  loop de loop
# 7470                                       control
# 7635                                       tuesday
# 7988                         echo and the bunnymen
# 8255                                     open eyes
# 8277                                 v island song
# 8336                                     sub focus
# 8810                         yuki muon madobe nite
#
#                                              Artist  Release  Duration  \
# 106                    adam szabo and johan vilborg      NaN       NaN
# 269   all my friends ft tinashe   chance the rapper      NaN       NaN
# 270                               allemaal door jou      NaN       NaN
# 309                                           amber      NaN       NaN
# 515                                            arty      NaN       NaN
# 730                              bastion soundtrack      NaN       NaN
# 809                                  beautiful liar      NaN       NaN
# 864                                better off alone      NaN       NaN
# 1414                                       cartoons      NaN       NaN
# 1422                                      cash cash      NaN       NaN
# 1433                                            cat      NaN       NaN
# 1714                                   cosmic girls      NaN       NaN
# 1938                                             dd      NaN       NaN
# 2790                                         fromis      NaN       NaN
# 2802                                 futurama theme      NaN       NaN
# 2977                               goodbye everyone      NaN       NaN
# 3200                                     henry viii      NaN       NaN
# 3227                             himouto umaru chan      NaN       NaN
# 3351                              i love your smile      NaN       NaN
# 3385                     im so lonesome i could cry      NaN       NaN
# 3516                                        jackson      NaN       NaN
# 3652                                jerry goldsmith      NaN       NaN
# 4063                     katamari damacy soundtrack      NaN       NaN
# 4426                                      lady gaga      NaN       NaN
# 4551                                   like i would      NaN       NaN
# 4587                                     lily white      NaN       NaN
# 5296                                         moguai      NaN       NaN
# 5651                                       nintendo      NaN       NaN
# 5652                                       nintendo      NaN       NaN
# 5732                                       norgaard      NaN       NaN
# 6027                                        pharaoh      NaN       NaN
# 6374                                  rebecca sugar      NaN       NaN
# 6655                      said the sky and illenium      NaN       NaN
# 6658                                     saint snow      NaN       NaN
# 6733                                        scandal      NaN       NaN
# 6793                                      sebastian      NaN       NaN
# 7323                          spongebob squarepants      NaN       NaN
# 7470                                  summer school      NaN       NaN
# 7635                          tennyson x mr carmack      NaN       NaN
# 7988                               the killing moon      NaN       NaN
# 8255                                         the xx      NaN       NaN
# 8277                             these new puritans      NaN       NaN
# 8336                                     tidal wave      NaN       NaN
# 8810                                    yuki nagato      NaN       NaN
#
#                                           matched_track  \
# 106                              Chrysalis (Two to One)
# 269   Snakehips - All My Friends (Official Video) ft...
# 270                                   Allemaal Door Jou
# 309                             Storms Are On the Ocean
# 515                                                Punk
# 730                     Mother, I'm Here (Zulf's Theme)
# 809                                      Beautiful Liar
# 864                     Alice Deejay - Better Off Alone
# 1414                                Day Oh (Ekkosangen)
# 1422             Speak With Your Heart - Ending Theme -
# 1433                                             He War
# 1714                                       Secret(비밀이야)
# 1938                                         Disco Bass
# 2790                                      Airplane Mode
# 2802     Futurama Series Theme (C. Tyng Extended Remix)
# 2977                                   Goodbye Everyone
# 3200             Pastime With Good Company - Henry VIII
# 3227                        Kakushinteki Metamaruphose!
# 3351                                  I Love Your Smile
# 3385                        I'm So Lonesome I Could Cry
# 3516                       0893 - OutKast - Ms. Jackson
# 3652  Flying Dreams from the Motion Picture "The Sec...
# 4063                              Katamari on the Rocks
# 4426  Joanne (Where Do You Think You're Goin'?) - Pi...
# 4551                                ZAYN - LIKE I WOULD
# 4587                       lily white -shunjou romantic
# 5296            Something Something Champs (radio edit)
# 5651        Lifelight Remix (Super Smash Bros Ultimate)
# 5652        Lifelight Remix (Super Smash Bros Ultimate)
# 5732                                           Nørgaard
# 6027  Dance On The Moon (ft. Theophilus London & Pau...
# 6374  For Just One Day Let's Only Think about (Love)...
# 6655  Painted White (Au5 & Fractal Remix)(Feat. Said...
# 6658                            saint snow - crash mind
# 6733                                           Stealin’
# 6793  Love In Motion "Funkt-Out" Remix - SebastiAn f...
# 7323                                       Loop de Loop
# 7470         Love Is In Control (Finger On The Trigger)
# 7635  Tennyson x Mr. Carmack - Thursday (feat. BJ Th...
# 7988          Echo And The Bunny Men - The Killing Moon
# 8255                          Open the eyes of my heart
# 8277                                    V (Island Song)
# 8336                                         Tidal Wave
# 8810                           Yuki, Muon, Madobe nite.
#
#                                          matched_artist  \
# 106   Tritonal and Linney feat. Johan Vilborg & Adam...
# 269                                           Snakehips
# 270                                        Bart Peeters
# 309                                       Amber Rubarth
# 515                                Ferry Corsten & ARTY
# 730                                         Darren Korb
# 809                                 Beyoncé and Shakira
# 864                                        Alice Deejay
# 1414                                           Cartoons
# 1422  Makhlouf, Alex & Makhlouf, Jean Paul of Cash Cash
# 1433                                          Cat Power
# 1714                          WJSN (Cosmic Girls)(우주소녀)
# 1938                                         D.D. Sound
# 2790                                           fromis_9
# 2802                                   Christopher Tyng
# 2977                                          Siinamota
# 3200                     The New World Renaissance Band
# 3227                                        Tanaka Aimi
# 3351                                            Shanice
# 3385            Hank Williams with The Drifting Cowboys
# 3516                                            Outkast
# 3652                     Katie Campbell, Dominik Hauser
# 4063                                    Masayuki Tanaka
# 4426                                          Lady Gaga
# 4551                                               zayn
# 4587                                         Love Live!
# 5296   Kaskade & Moguai feat. Zip Zip Through the Night
# 5651                                            Xontron
# 5652                                            Xontron
# 5732                                       The Vaccines
# 6027                                       Travi$ Scott
# 6374                      Steven Universe;Rebecca Sugar
# 6655                                           Illenium
# 6658                                         Love Live!
# 6733                                              Queen
# 6793                                           Skrillex
# 7323                                               Ween
# 7470                                       Donna Summer
# 7635                                           Red Bull
# 7988                                Echo & the Bunnymen
# 8255                                    Various Artists
# 8277                                 These New Puritans
# 8336                                 Sub Focus, Alpines
# 8810                                   長門有希 (C.V. 茅原実里)
#
#                                           matched_album  matched_duration  \
# 106                                            Coalesce        283.000000
# 269                                           Snakehips        230.000000
# 270                               Slimmer Dan De Zanger        228.000000
# 309                         Sessions from the 17th Ward        219.000000
# 515                                                Punk        385.000000
# 730                         Bastion Original Soundtrack        137.000000
# 809                                      Beautiful Liar        201.549000
# 864                                    Better Off Alone        215.562449
# 1414                                     Greatest Toons        216.000000
# 1422  SONIC COLORS: ULTIMATE ORIGINAL SOUNDTRACK: Re...        296.000000
# 1433                                       You Are Free        210.000000
# 1714                                         THE SECRET        223.000000
# 1938                          2001 The Best Of DD Sound        199.000000
# 2790                                       9 WAY TICKET        183.000000
# 2802              Futurama Main Theme (From "Futurama")        301.000000
# 2977                                              Alive        267.000000
# 3200                                    Live the Legend        213.000000
# 3227  Himouto! Umaru-chan OP Single - Kakushinteki M...        212.000000
# 3351                                  I Love Your Smile        258.000000
# 3385  Country Music: A Film by Ken Burns: The Soundt...        167.453333
# 3516                          1001 Songs Before You Die        271.000000
# 3652  Flying Dreams - from the Motion Picture "The S...        212.000000
# 4063  Katamari Damacy (Original Soundtrack) -Katamar...        357.000000
# 4426  Joanne (Where Do You Think You're Goin'?) [Pia...        295.632000
# 4551                                        zayn Videos        206.000000
# 4587                                         Love Live!        273.528163
# 5296                                         I Remember        223.000000
# 5651                       NINTENDO WINTER MEGAMIX 2021        231.000000
# 5652                       NINTENDO WINTER MEGAMIX 2021        231.000000
# 5732                                           Nørgaard         98.000000
# 6027                                        Owl Pharaoh        291.000000
# 6374      Steven Universe, Vol. 2 (Original Soundtrack)        228.713787
# 6655                             Painted White - Single        372.427755
# 6658                                         Love Live!        259.892245
# 6733                                            Scandal        240.000000
# 6793                                            Remixes        257.000000
# 7323                              SpongeBob SquarePants         61.000000
# 7470                           80s Back to School - CD3        224.000000
# 7635  Tennyson and Mr. Carmack - Tuesday Wednesday T...        244.000000
# 7988                                Echo & the Bunnymen        350.179375
# 8255  Songs 4 Worship vol XX, Praise God, The UK Col...        278.230204
# 8277                                     Field of Reeds        556.000000
# 8336                                              Torus        228.000000
# 8810  The Melancholy of Haruhi Suzumiya Character So...        270.000000
#
#               status  match_score instrumental
# 106   low_confidence     0.148936        False
# 269   low_confidence     0.403162        False
# 270   low_confidence     0.206897        False
# 309   low_confidence     0.456349        False
# 515   low_confidence     0.363636        False
# 730   low_confidence     0.364721        False
# 809   low_confidence     0.303030        False
# 864   low_confidence     0.399826        False
# 1414  low_confidence     0.562500        False
# 1422  low_confidence     0.548485        False
# 1433  low_confidence     0.480769        False
# 1714  low_confidence     0.562500        False
# 1938  low_confidence     0.272727        False
# 2790  low_confidence     0.428571        False
# 2802  low_confidence     0.295495        False
# 2977  low_confidence     0.080000        False
# 3200  low_confidence     0.559836        False
# 3227  low_confidence     0.281731        False
# 3351  low_confidence     0.208333        False
# 3385  low_confidence     0.192487        False
# 3516  low_confidence     0.376190        False
# 3652  low_confidence     0.233860        False
# 4063  low_confidence     0.548780        False
# 4426  low_confidence     0.573171        False
# 4551  low_confidence     0.190476        False
# 4587  low_confidence     0.538690        False
# 5296  low_confidence     0.487500        False
# 5651  low_confidence     0.460000        False
# 5652  low_confidence     0.492683        False
# 5732  low_confidence     0.150000        False
# 6027  low_confidence     0.559524        False
# 6374  low_confidence     0.568783        False
# 6655  low_confidence     0.513258        False
# 6658  low_confidence     0.404762        False
# 6733  low_confidence     0.250000        False
# 6793  low_confidence     0.436488        False
# 7323  low_confidence     0.540000        False
# 7470  low_confidence     0.520000        False
# 7635  low_confidence     0.231128        False
# 7988  low_confidence     0.562121        False
# 8255  low_confidence     0.312325        False
# 8277  low_confidence     0.571429        False
# 8336  low_confidence     0.163743        False
# 8810  low_confidence     0.500000        False
